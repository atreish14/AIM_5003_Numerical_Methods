# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
# Linear regression using sklearn
# Input: t data and y data
# Output: linear regression 
td = np.array([1, 2, 3, 4, 5, 6])
yd = np.array([3, 5, 9.2, 11, 14.5, 19])
model = LinearRegression(fit_intercept=True)
model.fit(td[:, np.newaxis], yd)
tfit = np.linspace(0, 7)
yfit = model.predict(tfit[:, np.newaxis])
model.fit(td[:, np.newaxis], yd)
plt.scatter(td, yd)
plt.plot(tfit, yfit, 'r')
print("Model slope:    ", model.coef_[0])
print("Model intercept:", model.intercept_)
# Out:
# Model slope:     3.1514285714285712
# Model intercept: -0.7466666666666661

# %%
model = linear_model.Ridge(fit_intercept=True,alpha=0.5)
model.fit(td[:, np.newaxis], yd)
tfit = np.linspace(0, 7)
yfit = model.predict(tfit[:, np.newaxis])
model.fit(td[:, np.newaxis], yd)
plt.scatter(td, yd)
plt.plot(tfit, yfit, 'r')
print("Model slope:    ", model.coef_[0])
print("Model intercept:", model.intercept_)
# Out:
# Model slope:     3.063888888888889
# Model intercept: -0.4402777777777782
